# %% [markdown]
# # CUBS EDA
#
# Notebook ini untuk eksplorasi awal dataset CUBS: distribusi center, IMT, SNR, dan overlay mask.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# TODO: load metadata CSV dan lakukan ringkasan jumlah data per center
